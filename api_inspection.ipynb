# %%
import requests
import json
import pandas as pd
import numpy as np
import datetime
from pprint import pprint

# %%
url = "https://data.cityofchicago.org/resource/4ijn-s7e5.json?$limit=100000"

# %%
response = requests.get(url)
print(response.url)
# Out:
# https://data.cityofchicago.org/resource/4ijn-s7e5.json?$limit=100000

# %%
data = response.json()
# pprint(data)

# %%
inspection_df = pd.read_json(url)

# %%
# inspection_df

# %%
unique_restaurants = inspection_df["aka_name"].unique()
facility_types = inspection_df["facility_type"].unique()
facility_types_corrected = inspection_df["facility_type"].str.upper().unique()
inspection_types = inspection_df["inspection_type"].unique()
licenses = inspection_df["license_"].unique()
# inspection_df["location"][0]

# %%
# inspection_df["violations"][0]

# %%
violations_split_up = inspection_df["violations"].str.split("|", 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-af73b614eeb3> in <module>
# ----> 1 violations_split_up = inspection_df["violations"].str.split("|", 20)
#
# NameError: name 'inspection_df' is not defined

# %%
# new_df = pd.DataFrame(violations_split_up)
new_df = inspection_df
new_df["inspection_date"]=inspection_df["inspection_date"].str.slice(stop = 10)

# %%
# print(new_df["violations"][0])
# print(violations_split_up[0])

# %%
new_df["first_violation"] = ""
new_df["second_violation"] = ""
new_df["third_violation"] = ""
new_df["fourth_violation"] = ""
new_df["fifth_violation"] = ""
new_df["sixth_violation"] = ""
new_df["seventh_violation"] = ""
new_df["eighth_violation"] = ""
new_df["ninth_violation"] = ""
new_df["tenth_violation"] = ""
new_df["eleventh_violation"] = ""
new_df["twelf_violation"] = ""
new_df["thirteenth_violation"] = ""
new_df["fourteenth_violation"] = ""
new_df["fifteenth_violation"] = ""
new_df["sixteenth_violation"] = ""
new_df["seventeenth_violation"] = ""
new_df["eighteenth_violation"] = ""
new_df["ninteeth_violation"] = ""
new_df["twentieth_violation"] = ""
# new_df

# %%
# i=-1
for index, row in new_df.iterrows():
#     i += 1
#     if i == 100:
#         break
#     else:
        try:
            new_df.loc[index, "first_violation"] = violations_split_up[index][0]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "second_violation"] = violations_split_up[index][1]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "third_violation"] = violations_split_up[index][2]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "fourth_violation"] = violations_split_up[index][3]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "fifth_violation"] = violations_split_up[index][4]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "sixth_violation"] = violations_split_up[index][5]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "seventh_violation"] = violations_split_up[index][6]
        except (KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "eighth_violation"] = violations_split_up[index][7]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "ninth_violation"] = violations_split_up[index][8]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "tenth_violation"] = violations_split_up[index][9]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "eleventh_violation"] = violations_split_up[index][10]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "twelf_violation"] = violations_split_up[index][11]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "thirteenth_violation"] = violations_split_up[index][12]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "fourteenth_violation"] = violations_split_up[index][13]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "fifteenth_violation"] = violations_split_up[index][14]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "sixteenth_violation"] = violations_split_up[index][15]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "seventeenth_violation"] = violations_split_up[index][16]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "eighteenth_violation"] = violations_split_up[index][17]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "ninteeth_violation"] = violations_split_up[index][18]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue
        try:
            new_df.loc[index, "twentieth_violation"] = violations_split_up[index][19]
        except (TypeError, KeyError, IndexError):
#             print(f"No more violations for {i}")
            continue

# %%
# print(new_df["first_violation"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e3221d9aa15f> in <module>
#       1 # print(new_df["first_violation"])
# ----> 2 new_df
#
# NameError: name 'new_df' is not defined

# %%
# new_df.to_csv("inspection_data.csv", index=False)

# %%
# full_inspection_data = new_df

full_inspection_data = pd.read_csv("inspection_data.csv")
# Out:
# C:\Users\prins\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (32,33,34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# full_inspection_data["inspection_date"][0]
# Out:
# '2019-09-17'

# %%
# slice_test = full_inspection_data["inspection_date"].str.slice(stop = 10)
# full_inspection_data["inspection_date"]=slice_test

time_test = pd.to_datetime(full_inspection_data["inspection_date"], format='%Y%m%d', infer_datetime_format=True)

# %%
inspection_data_2019 = full_inspection_data.loc[(time_test >= "2019-01-01" ) & (time_test <= "2019-12-31")]
inspection_data_2018 = full_inspection_data.loc[(time_test >= "2018-01-01" ) & (time_test <= "2018-12-31")]
inspection_data_2017 = full_inspection_data.loc[(time_test >= "2017-01-01" ) & (time_test <= "2017-12-31")]
inspection_data_2016 = full_inspection_data.loc[(time_test >= "2016-01-01" ) & (time_test <= "2016-12-31")]
inspection_data_2015 = full_inspection_data.loc[(time_test >= "2015-01-01" ) & (time_test <= "2015-12-31")]
inspection_data_2014 = full_inspection_data.loc[(time_test >= "2014-01-01" ) & (time_test <= "2014-12-31")]

# %%
inspection_data_2014
# Out:
#                         address                               aka_name  \
# 94776      2800 W DIVERSEY AVE                                 POPEYES
# 94777     1408 W DIVERSEY PKWY                                     NaN
# 94778        1535 W MADISON ST               BILLY GOAT TAVERN & GRILL
# 94779      1009-1011 W LAKE ST   THE CORNED BEEF FACTORY SANDWICH SHOP
# 94780            750 N RUSH ST             J.J. PEPPERS FOOD STORE #20
# 94781       4407 N KIMBALL AVE                       MICHOACANA BAKERY
# 94782        8324 S KEDZIE AVE                    D&D PLACE RESTAURANT
# 94783         3301 W NORTH AVE                        FOREMOST LIQUORS
# 94784          1232 S CANAL ST                                  SUBWAY
# 94785     3721 W FULLERTON AVE              SWEET AND SOUR EXPRESS INC
# 94786        5501 N HARLEM AVE                       TACO BURRITO KING
# 94787     3719 W FULLERTON AVE                    ABRAHAM LINCOLN FOOD
# ...

# %%
inspection_data_2019.to_csv("inspection_data_2019.csv", index=False)
inspection_data_2018.to_csv("inspection_data_2018.csv", index=False)
inspection_data_2017.to_csv("inspection_data_2017.csv", index=False)
inspection_data_2016.to_csv("inspection_data_2016.csv", index=False)
inspection_data_2015.to_csv("inspection_data_2015.csv", index=False)
inspection_data_2014.to_csv("inspection_data_2014.csv", index=False)

# %%
revisited_inspection_data = pd.read_csv("inspection_data_2019.csv")

# %%
revisited_inspection_data["violation_count"] = 0

# %%
violations_lists = violations_split_up = revisited_inspection_data["violations"].str.split("|", 20)

# %%
revisited_inspection_data["violations"] = violations_lists

# %%
revisited_inspection_data
# Out:
#                            address                                 aka_name  \
# 0           3624 W WRIGHTWOOD AVE             NECESSARY & SUFFICIENT COFFEE
# 1                 311 S WACKER DR                              SKY DINE 311
# 2      1812-1814 W IRVING PARK RD                      I-CAFE SUKUR'S PLACE
# 3               11601 W TOUHY AVE            MCDONALD'S  (T3 HK FOOD COURT)
# 4                2300 S THROOP ST                             LA CHAPARRITA
# 5               131 S DEARBORN ST                                   CONVENE
# 6                 6158 N CLARK ST                               ALEXANDER'S
# 7          4001 W WASHINGTON BLVD                            T&T'S RED HOTS
# 8                1010 S DELANO CT                                   PACINOS
# 9                1010 S DELANO CT                                   PACINOS
# 10           7904 S VINCENNES AVE                                KING GYROS
# ...

# %%
for index, row in revisited_inspection_data.iterrows():
        try:
            violation_count = len(revisited_inspection_data["violations"][index])
            revisited_inspection_data["violation_count"][index] = violation_count
        except (TypeError, KeyError, ValueError):
            revisited_inspection_data["violation_count"][index] = 0
# Out:
# C:\Users\prins\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\prins\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
updated_inspection_data_2019 = revisited_inspection_data

# %%
updated_inspection_data_2019 = updated_inspection_data_2019.drop(updated_inspection_data_2019.loc[:, 'first_violation':'twentieth_violation'].columns, axis = 1)

# %%
updated_inspection_data_2019 = updated_inspection_data_2019.drop(["location", "zip", "state","city","dba_name", "violations"], axis=1)

# %%
# updated_inspection_data_2019.to_csv("refined_inspection_data_2019.csv", index=False)

# %%
grouped_by_license = updated_inspection_data_2019.groupby(["license_"])

# %%
# updated_inspection_data_2019["average_violations_per_inspection"] = grouped_by_license["violation_count"].mean()
# updated_inspection_data_2019["times_inspected"] = grouped_by_license["violation_count"].count()

# %%
updated_inspection_data_2019
# Out:
#                            address                                 aka_name  \
# 0           3624 W WRIGHTWOOD AVE             NECESSARY & SUFFICIENT COFFEE
# 1                 311 S WACKER DR                              SKY DINE 311
# 2      1812-1814 W IRVING PARK RD                      I-CAFE SUKUR'S PLACE
# 3               11601 W TOUHY AVE            MCDONALD'S  (T3 HK FOOD COURT)
# 4                2300 S THROOP ST                             LA CHAPARRITA
# 5               131 S DEARBORN ST                                   CONVENE
# 6                 6158 N CLARK ST                               ALEXANDER'S
# 7          4001 W WASHINGTON BLVD                            T&T'S RED HOTS
# 8                1010 S DELANO CT                                   PACINOS
# 9                1010 S DELANO CT                                   PACINOS
# 10           7904 S VINCENNES AVE                                KING GYROS
# ...

# %%
updated_inspection_data_2019.to_csv("refined_inspection_data_2019.csv", index=False)

# %%
violation_summary = pd.DataFrame(columns=["license_","avg_violations","times_inspected"])

# %%
violation_summary["license_"] = updated_inspection_data_2019["license_"].drop_duplicates()

# %%
violation_summary = violation_summary.set_index("license_")

# %%
violation_summary["avg_violations"] = grouped_by_license["violation_count"].mean()
violation_summary["times_inspected"] = grouped_by_license["violation_count"].count()

# %%
violation_summary.head()
# Out:
#            avg_violations  times_inspected
# license_
# 2677227.0             4.0              3.0
# 2670530.0             0.0              2.0
# 2333622.0            11.0              2.0
# 1140128.0             5.0              3.0
# 2689521.0             0.0              2.0

# %%
violation_summary_.to_csv("violation_summary_2019.csv", index=True)
